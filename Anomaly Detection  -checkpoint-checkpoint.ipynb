# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv('Sample scores.csv')
df
# Out:
#     Overs  Scores
# 0       1      15
# 1       2      10
# 2       3      17
# 3       4      10
# 4       5      12
# 5       6      20
# 6       7     100
# 7       8       7
# 8       9       8
# 9      10      11
# 10     11     100
# 11     12      14
# 12     13       3
# 13     14     100
# 14     15      11
# 15     16      13
# 16     17     100
# 17     18      16
# 18     19      26
# 19     20      30

# %%
model=IsolationForest(n_estimators=1000,max_samples='auto',contamination=float(0.2),max_features=1.0)
model.fit(df[['Scores']])
# Out:
# IsolationForest(contamination=0.2, n_estimators=1000)

# %%
df['scores']=model.decision_function(df[['Scores']])
df['anomaly']=model.predict(df[['Scores']])
df.head(20)
# Out:
#     Overs  Scores    scores  anomaly
# 0       1      15  0.217966        1
# 1       2      10  0.234759        1
# 2       3      17  0.193176        1
# 3       4      10  0.234759        1
# 4       5      12  0.233374        1
# 5       6      20  0.123943        1
# 6       7     100 -0.024256       -1
# 7       8       7  0.146216        1
# 8       9       8  0.174374        1
# 9      10      11  0.247619        1
# 10     11     100 -0.024256       -1
# 11     12      14  0.223875        1
# 12     13       3  0.006064        1
# 13     14     100 -0.024256       -1
# 14     15      11  0.247619        1
# 15     16      13  0.231063        1
# 16     17     100 -0.024256       -1
# 17     18      16  0.211475        1
# 18     19      26  0.062341        1
# 19     20      30  0.010472        1

# %%
outliers_counter = len(df[df['Scores'] > 36])
outliers_counter
# Out:
# 4
